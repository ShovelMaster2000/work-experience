# %%
import pandas as pd
import numpy as np
import requests # for web-download
import io # for web-download
import re # for data processing

# %% [markdown]
# # Обработка DataFrame

# %% [markdown]
# **Задача 1**
#
# На основании данных портала "Открытые данные России" о результатах Химического анализа родника в Нескучном саду https://data.gov.ru/opendata/7708660670-rodnik-neskuchniy-sad средствами библиотеки Pandas сформируйте поле выводов по каждому анализирумомому параметру. Например, по показателю pH получен результат 8.4 единицы pH при нормативе от 6 до 9 единиц pH. Т.о. по данному показателю результат анализа в норме. Для решения задачи необходимо программно "прочитать и понять" значение столбца "Норматив" и выделенное численное значение сравнить с нормативом согласно логике норматива. Например, 6 >= pH >= 9. В итоговом DataFrame столбец "Показатель" сделайте индексным.

# %%
# загружаем данные
df=pd.read_csv("Химический анализ родника в Нескучном саду.csv", sep=',', index_col ='Показатель' )
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH                8.4
# Запах                                             баллы                  1
# Цветность                                       градусы            б/цвета
# Жёсткость                                   мг-эквл/дм3  9.199999999999999
# Аммиак и аммоний-ион (по азоту)                  мг/дм3               0.42
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3                 24
# Фосфаты (P)                                      мг/дм3               0.36
# Хлориды (Cl)                                     мг/дм3                200
# Сульфаты (SO4)                                   мг/дм3              189.5
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3               0.55
# Общая минерализация (сухой остаток)              мг/дм3                590
# Окисляемость перманганатная                      мг/дм3                  2
#
#                                               Норматив
# Показатель
# pH                                      в пределах 6-9
# Запах                                     не более 2-3
# Цветность                                  не более 30
# Жёсткость                              в пределах 7-10
# Аммиак и аммоний-ион (по азоту)           не более 1,5
# Нитриты (по NO2)                          не более 3,3
# Нитраты (по NO3)                           не более 45
# Фосфаты (P)                               не более 3,5
# Хлориды (Cl)                              не более 350
# Сульфаты (SO4)                            не более 500
# Железо (включая хлорное железо) по Fe     не более 0,3
# Нефть                                     не более 0,3
# Общая минерализация (сухой остаток)      не более 1000
# Окисляемость перманганатная               не более 0,5

# %%
# разобьем "норматив" по столцам
sep_columns = df['Норматив'].str.split(expand=True)
temporary_df = sep_columns[2].str.split('-', expand=True)

# %%
# из полученных столбцов сделаем датафрейм условии
sep_columns['Условие'] = sep_columns[0] + ' ' + sep_columns[1]
sep_columns['Левая граница'] = temporary_df[0]
sep_columns['Правая граница'] = temporary_df[1]
condition_df = sep_columns.drop([0, 1, 2], axis=1)
condition_df
# Out:
#                                           Условие Левая граница Правая граница
# Показатель
# pH                                     в пределах             6              9
# Запах                                    не более             2              3
# Цветность                                не более            30           None
# Жёсткость                              в пределах             7             10
# Аммиак и аммоний-ион (по азоту)          не более           1,5           None
# Нитриты (по NO2)                         не более           3,3           None
# Нитраты (по NO3)                         не более            45           None
# Фосфаты (P)                              не более           3,5           None
# Хлориды (Cl)                             не более           350           None
# Сульфаты (SO4)                           не более           500           None
# Железо (включая хлорное железо) по Fe    не более           0,3           None
# Нефть                                    не более           0,3           None
# Общая минерализация (сухой остаток)      не более          1000           None
# Окисляемость перманганатная              не более           0,5           None

# %%
# правую границу с пустыми значениями заполним значениями из левой границы
mask = condition_df['Правая граница'].isnull()
condition_df.loc[mask, 'Правая граница'] = condition_df.loc[mask, 'Левая граница']
condition_df
# Out:
#                                           Условие Левая граница Правая граница
# Показатель
# pH                                     в пределах             6              9
# Запах                                    не более             2              3
# Цветность                                не более            30             30
# Жёсткость                              в пределах             7             10
# Аммиак и аммоний-ион (по азоту)          не более           1,5            1,5
# Нитриты (по NO2)                         не более           3,3            3,3
# Нитраты (по NO3)                         не более            45             45
# Фосфаты (P)                              не более           3,5            3,5
# Хлориды (Cl)                             не более           350            350
# Сульфаты (SO4)                           не более           500            500
# Железо (включая хлорное железо) по Fe    не более           0,3            0,3
# Нефть                                    не более           0,3            0,3
# Общая минерализация (сухой остаток)      не более          1000           1000
# Окисляемость перманганатная              не более           0,5            0,5

# %%
# объединим начальный df и df условий
df = pd.concat([df, condition_df], axis=1)
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH                8.4
# Запах                                             баллы                  1
# Цветность                                       градусы            б/цвета
# Жёсткость                                   мг-эквл/дм3  9.199999999999999
# Аммиак и аммоний-ион (по азоту)                  мг/дм3               0.42
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3                 24
# Фосфаты (P)                                      мг/дм3               0.36
# Хлориды (Cl)                                     мг/дм3                200
# Сульфаты (SO4)                                   мг/дм3              189.5
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3               0.55
# Общая минерализация (сухой остаток)              мг/дм3                590
# Окисляемость перманганатная                      мг/дм3                  2
#
#                                               Норматив     Условие  \
# Показатель
# pH                                      в пределах 6-9  в пределах
# Запах                                     не более 2-3    не более
# Цветность                                  не более 30    не более
# Жёсткость                              в пределах 7-10  в пределах
# Аммиак и аммоний-ион (по азоту)           не более 1,5    не более
# Нитриты (по NO2)                          не более 3,3    не более
# Нитраты (по NO3)                           не более 45    не более
# Фосфаты (P)                               не более 3,5    не более
# Хлориды (Cl)                              не более 350    не более
# Сульфаты (SO4)                            не более 500    не более
# Железо (включая хлорное железо) по Fe     не более 0,3    не более
# Нефть                                     не более 0,3    не более
# Общая минерализация (сухой остаток)      не более 1000    не более
# Окисляемость перманганатная               не более 0,5    не более
#
#                                       Левая граница Правая граница
# Показатель
# pH                                                6              9
# Запах                                             2              3
# Цветность                                        30             30
# Жёсткость                                         7             10
# Аммиак и аммоний-ион (по азоту)                 1,5            1,5
# Нитриты (по NO2)                                3,3            3,3
# Нитраты (по NO3)                                 45             45
# Фосфаты (P)                                     3,5            3,5
# Хлориды (Cl)                                    350            350
# Сульфаты (SO4)                                  500            500
# Железо (включая хлорное железо) по Fe           0,3            0,3
# Нефть                                           0,3            0,3
# Общая минерализация (сухой остаток)            1000           1000
# Окисляемость перманганатная                     0,5            0,5

# %%
# заменим строковое значение в числовом столце на число
df.at['Цветность', 'Результат анализа'] = 0
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH                8.4
# Запах                                             баллы                  1
# Цветность                                       градусы                  0
# Жёсткость                                   мг-эквл/дм3  9.199999999999999
# Аммиак и аммоний-ион (по азоту)                  мг/дм3               0.42
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3                 24
# Фосфаты (P)                                      мг/дм3               0.36
# Хлориды (Cl)                                     мг/дм3                200
# Сульфаты (SO4)                                   мг/дм3              189.5
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3               0.55
# Общая минерализация (сухой остаток)              мг/дм3                590
# Окисляемость перманганатная                      мг/дм3                  2
#
#                                               Норматив     Условие  \
# Показатель
# pH                                      в пределах 6-9  в пределах
# Запах                                     не более 2-3    не более
# Цветность                                  не более 30    не более
# Жёсткость                              в пределах 7-10  в пределах
# Аммиак и аммоний-ион (по азоту)           не более 1,5    не более
# Нитриты (по NO2)                          не более 3,3    не более
# Нитраты (по NO3)                           не более 45    не более
# Фосфаты (P)                               не более 3,5    не более
# Хлориды (Cl)                              не более 350    не более
# Сульфаты (SO4)                            не более 500    не более
# Железо (включая хлорное железо) по Fe     не более 0,3    не более
# Нефть                                     не более 0,3    не более
# Общая минерализация (сухой остаток)      не более 1000    не более
# Окисляемость перманганатная               не более 0,5    не более
#
#                                       Левая граница Правая граница
# Показатель
# pH                                                6              9
# Запах                                             2              3
# Цветность                                        30             30
# Жёсткость                                         7             10
# Аммиак и аммоний-ион (по азоту)                 1,5            1,5
# Нитриты (по NO2)                                3,3            3,3
# Нитраты (по NO3)                                 45             45
# Фосфаты (P)                                     3,5            3,5
# Хлориды (Cl)                                    350            350
# Сульфаты (SO4)                                  500            500
# Железо (включая хлорное железо) по Fe           0,3            0,3
# Нефть                                           0,3            0,3
# Общая минерализация (сухой остаток)            1000           1000
# Окисляемость перманганатная                     0,5            0,5

# %%
df['Левая граница'] = df['Левая граница'].str.replace(',', '.')
df['Правая граница'] = df['Правая граница'].str.replace(',', '.')
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH                8.4
# Запах                                             баллы                  1
# Цветность                                       градусы                  0
# Жёсткость                                   мг-эквл/дм3  9.199999999999999
# Аммиак и аммоний-ион (по азоту)                  мг/дм3               0.42
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3                 24
# Фосфаты (P)                                      мг/дм3               0.36
# Хлориды (Cl)                                     мг/дм3                200
# Сульфаты (SO4)                                   мг/дм3              189.5
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3               0.55
# Общая минерализация (сухой остаток)              мг/дм3                590
# Окисляемость перманганатная                      мг/дм3                  2
#
#                                               Норматив     Условие  \
# Показатель
# pH                                      в пределах 6-9  в пределах
# Запах                                     не более 2-3    не более
# Цветность                                  не более 30    не более
# Жёсткость                              в пределах 7-10  в пределах
# Аммиак и аммоний-ион (по азоту)           не более 1,5    не более
# Нитриты (по NO2)                          не более 3,3    не более
# Нитраты (по NO3)                           не более 45    не более
# Фосфаты (P)                               не более 3,5    не более
# Хлориды (Cl)                              не более 350    не более
# Сульфаты (SO4)                            не более 500    не более
# Железо (включая хлорное железо) по Fe     не более 0,3    не более
# Нефть                                     не более 0,3    не более
# Общая минерализация (сухой остаток)      не более 1000    не более
# Окисляемость перманганатная               не более 0,5    не более
#
#                                       Левая граница Правая граница
# Показатель
# pH                                                6              9
# Запах                                             2              3
# Цветность                                        30             30
# Жёсткость                                         7             10
# Аммиак и аммоний-ион (по азоту)                 1.5            1.5
# Нитриты (по NO2)                                3.3            3.3
# Нитраты (по NO3)                                 45             45
# Фосфаты (P)                                     3.5            3.5
# Хлориды (Cl)                                    350            350
# Сульфаты (SO4)                                  500            500
# Железо (включая хлорное железо) по Fe           0.3            0.3
# Нефть                                           0.3            0.3
# Общая минерализация (сухой остаток)            1000           1000
# Окисляемость перманганатная                     0.5            0.5

# %%
df.dtypes
# Out:
# Единица измерений    object
# Результат анализа    object
# Норматив             object
# Условие              object
# Левая граница        object
# Правая граница       object
# dtype: object

# %%
# скорректируем тип данных столбцов
df['Единица измерений'] = df['Единица измерений'].astype(str)
df['Результат анализа'] = df['Результат анализа'].astype(float)
df['Норматив'] = df['Норматив'].astype(str)
df['Условие'] = df['Условие'].astype(str)
df['Левая граница'] = df['Левая граница'].astype(float)
df['Правая граница'] = df['Правая граница'].astype(float)

# %%
df.dtypes
# Out:
# Единица измерений     object
# Результат анализа    float64
# Норматив              object
# Условие               object
# Левая граница        float64
# Правая граница       float64
# dtype: object

# %%
# используем условие для заполнения столбца качества
mask_positiv = (df['Условие'] == 'не более') & (df['Правая граница'] > df['Результат анализа'])
mask_negativ = (df['Условие'] == 'не более') & (df['Правая граница'] < df['Результат анализа'])
df.loc[mask_positiv, 'Качество'] = 'Хорошо'
df.loc[mask_negativ, 'Качество'] = 'Плохо'
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH              8.400
# Запах                                             баллы              1.000
# Цветность                                       градусы              0.000
# Жёсткость                                   мг-эквл/дм3              9.200
# Аммиак и аммоний-ион (по азоту)                  мг/дм3              0.420
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3             24.000
# Фосфаты (P)                                      мг/дм3              0.360
# Хлориды (Cl)                                     мг/дм3            200.000
# Сульфаты (SO4)                                   мг/дм3            189.500
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3              0.550
# Общая минерализация (сухой остаток)              мг/дм3            590.000
# Окисляемость перманганатная                      мг/дм3              2.000
#
#                                               Норматив     Условие  \
# Показатель
# pH                                      в пределах 6-9  в пределах
# Запах                                     не более 2-3    не более
# Цветность                                  не более 30    не более
# Жёсткость                              в пределах 7-10  в пределах
# Аммиак и аммоний-ион (по азоту)           не более 1,5    не более
# Нитриты (по NO2)                          не более 3,3    не более
# Нитраты (по NO3)                           не более 45    не более
# Фосфаты (P)                               не более 3,5    не более
# Хлориды (Cl)                              не более 350    не более
# Сульфаты (SO4)                            не более 500    не более
# Железо (включая хлорное железо) по Fe     не более 0,3    не более
# Нефть                                     не более 0,3    не более
# Общая минерализация (сухой остаток)      не более 1000    не более
# Окисляемость перманганатная               не более 0,5    не более
#
#                                        Левая граница  Правая граница Качество
# Показатель
# pH                                               6.0             9.0      NaN
# Запах                                            2.0             3.0   Хорошо
# Цветность                                       30.0            30.0   Хорошо
# Жёсткость                                        7.0            10.0      NaN
# Аммиак и аммоний-ион (по азоту)                  1.5             1.5   Хорошо
# Нитриты (по NO2)                                 3.3             3.3   Хорошо
# Нитраты (по NO3)                                45.0            45.0   Хорошо
# Фосфаты (P)                                      3.5             3.5   Хорошо
# Хлориды (Cl)                                   350.0           350.0   Хорошо
# Сульфаты (SO4)                                 500.0           500.0   Хорошо
# Железо (включая хлорное железо) по Fe            0.3             0.3   Хорошо
# Нефть                                            0.3             0.3    Плохо
# Общая минерализация (сухой остаток)           1000.0          1000.0   Хорошо
# Окисляемость перманганатная                      0.5             0.5    Плохо

# %%
# используем условие для заполнения столбца качества
mask_positiv = (
    (df['Условие'] == 'в пределах') & 
    (df['Правая граница'] >= df['Результат анализа']) & 
    (df['Левая граница'] <= df['Результат анализа'])
    )

df.loc[mask_positiv, 'Качество'] = 'Хорошо'
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH              8.400
# Запах                                             баллы              1.000
# Цветность                                       градусы              0.000
# Жёсткость                                   мг-эквл/дм3              9.200
# Аммиак и аммоний-ион (по азоту)                  мг/дм3              0.420
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3             24.000
# Фосфаты (P)                                      мг/дм3              0.360
# Хлориды (Cl)                                     мг/дм3            200.000
# Сульфаты (SO4)                                   мг/дм3            189.500
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3              0.550
# Общая минерализация (сухой остаток)              мг/дм3            590.000
# Окисляемость перманганатная                      мг/дм3              2.000
#
#                                               Норматив     Условие  \
# Показатель
# pH                                      в пределах 6-9  в пределах
# Запах                                     не более 2-3    не более
# Цветность                                  не более 30    не более
# Жёсткость                              в пределах 7-10  в пределах
# Аммиак и аммоний-ион (по азоту)           не более 1,5    не более
# Нитриты (по NO2)                          не более 3,3    не более
# Нитраты (по NO3)                           не более 45    не более
# Фосфаты (P)                               не более 3,5    не более
# Хлориды (Cl)                              не более 350    не более
# Сульфаты (SO4)                            не более 500    не более
# Железо (включая хлорное железо) по Fe     не более 0,3    не более
# Нефть                                     не более 0,3    не более
# Общая минерализация (сухой остаток)      не более 1000    не более
# Окисляемость перманганатная               не более 0,5    не более
#
#                                        Левая граница  Правая граница Качество
# Показатель
# pH                                               6.0             9.0   Хорошо
# Запах                                            2.0             3.0   Хорошо
# Цветность                                       30.0            30.0   Хорошо
# Жёсткость                                        7.0            10.0   Хорошо
# Аммиак и аммоний-ион (по азоту)                  1.5             1.5   Хорошо
# Нитриты (по NO2)                                 3.3             3.3   Хорошо
# Нитраты (по NO3)                                45.0            45.0   Хорошо
# Фосфаты (P)                                      3.5             3.5   Хорошо
# Хлориды (Cl)                                   350.0           350.0   Хорошо
# Сульфаты (SO4)                                 500.0           500.0   Хорошо
# Железо (включая хлорное железо) по Fe            0.3             0.3   Хорошо
# Нефть                                            0.3             0.3    Плохо
# Общая минерализация (сухой остаток)           1000.0          1000.0   Хорошо
# Окисляемость перманганатная                      0.5             0.5    Плохо

# %%
# удалим лишние столцы
df = df.drop(['Условие', 'Левая граница', 'Правая граница'], axis=1)
df
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH              8.400
# Запах                                             баллы              1.000
# Цветность                                       градусы              0.000
# Жёсткость                                   мг-эквл/дм3              9.200
# Аммиак и аммоний-ион (по азоту)                  мг/дм3              0.420
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3             24.000
# Фосфаты (P)                                      мг/дм3              0.360
# Хлориды (Cl)                                     мг/дм3            200.000
# Сульфаты (SO4)                                   мг/дм3            189.500
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3              0.550
# Общая минерализация (сухой остаток)              мг/дм3            590.000
# Окисляемость перманганатная                      мг/дм3              2.000
#
#                                               Норматив Качество
# Показатель
# pH                                      в пределах 6-9   Хорошо
# Запах                                     не более 2-3   Хорошо
# Цветность                                  не более 30   Хорошо
# Жёсткость                              в пределах 7-10   Хорошо
# Аммиак и аммоний-ион (по азоту)           не более 1,5   Хорошо
# Нитриты (по NO2)                          не более 3,3   Хорошо
# Нитраты (по NO3)                           не более 45   Хорошо
# Фосфаты (P)                               не более 3,5   Хорошо
# Хлориды (Cl)                              не более 350   Хорошо
# Сульфаты (SO4)                            не более 500   Хорошо
# Железо (включая хлорное железо) по Fe     не более 0,3   Хорошо
# Нефть                                     не более 0,3    Плохо
# Общая минерализация (сухой остаток)      не более 1000   Хорошо
# Окисляемость перманганатная               не более 0,5    Плохо

# %% [markdown]
# # Теория вероятности. События

# %% [markdown]
# Задача 2
#
# * В ящике 5 апельсинов и 4 яблока. Наудачу выбираются 3 фрукта. Какова вероятность, что все три фрукта – апельсины?
# * В интернете полученный аналитически ответ 0.119. Подтверждается ли он эксперементально?

# %%
import random

# %%
num_experiments = 1_000_000 
num_fruit = 3            
result_experiments = []
# проводим эксперименты
for experiment in range(1, num_experiments + 1):
  temporary_list = []
  # заполняем ящик
  box = ["apple"] * 4 + ['orange'] * 5 
  # вытаскиваем 3 фрукта из ящика
  for _ in range(num_fruit):
    fruit = random.choice(box)
    temporary_list.append(fruit)
    box.remove(fruit)
  result_experiments.append(temporary_list)
# формируем DataFrame с результатами
result_df = pd.DataFrame(result_experiments)
result_df.head()
# Out:
#         0       1       2
# 0  orange  orange   apple
# 1  orange   apple  orange
# 2  orange   apple  orange
# 3  orange  orange  orange
# 4  orange  orange   apple

# %%
# формируем условие где 3 фрукта апельсины
mask = ((result_df[0] == 'orange') &
        (result_df[1] == 'orange') &
        (result_df[2] == 'orange'))

# %%
# считаем вероятность
result_df.loc[mask, 'Result'] = 1
prob = result_df['Result'].sum() / num_experiments
print('Вероятность вытащить из ящика 3 апельсина подряд - {}'.format(prob))
# Out:
# Вероятность вытащить из ящика 3 апельсина подряд - 0.119311

# %% [markdown]
# Задача 3
#
# * Мастер, имея 10 деталей, из которых 3 – нестандартных, проверяет детали одну за другой, пока ему не попадется стандартная. Какова вероятность, что он проверит ровно две детали?
# * В интернете полученный аналитически ответ 7/30 или 0.23333. Подтверждается ли он эксперементально?

# %%
num_experiments = 100000
num_details = 2
result_experiments = []
# проводим эксперименты
for experiment in range(1, num_experiments + 1):
  temporary_list = []
  # создаем список деталей
  details = ['standard'] * 7 + ['non-standard'] * 3
  # проверяем детали
  for _ in range(num_details):
    detail = random.choice(details)
    temporary_list.append(detail)
    details.remove(detail)
  result_experiments.append(temporary_list)
# формируем DataFrame с результатами
result_df = pd.DataFrame(result_experiments)
result_df.head()
# Out:
#               0             1
# 0      standard      standard
# 1      standard  non-standard
# 2      standard      standard
# 3  non-standard      standard
# 4      standard      standard

# %%
# считаем вероятность
prob = len(result_df[(result_df[0] == 'non-standard') &
          (result_df[1] == 'standard')]) / num_experiments
print('Вероятность что вторая деталь стандартная - {}'.format(prob))
# Out:
# Вероятность что вторая деталь стандартная - 0.232
